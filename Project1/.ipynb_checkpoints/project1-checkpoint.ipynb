# %%
import os
import re
import csv
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# location = "C:\\Users\\Telahun\\Documents\\School\\CSE 632\\DataMining\\Project1\\"

# %%
pd.set_option('display.max_columns', 25)
pd.set_option('use_inf_as_na', True)

# %%
location = "C:\\Users\\Telahun\\Documents\\School\\CSE 632\\DataMining\\Project1\\"

# %%
df = pd.read_csv(location+"regames.csv", index_col='id_str')#, error_bad_lines=False)
# Out:
# C:\Users\Telahun\Anaconda3\envs\dmg\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (2,3,9,10,12,13,40,41,53,54,56,57,92,93,95,96,128,129,141,142,144,145,181,182,193,194,195,196,197,198,199,200,201,211,215,242,243,255,259,294,297,298,330,331,343,346,347,385,393,394,395,396,397,398,399,400,401,409,462,463,469,473,500,501,513,517,552,556,588,589,601,605,641,642,671,675,702,703,712,713,714,715,719,754,755,757,758,790,791,803,804,806,807,845,853,854,855,856,857,858,859,860,861,869,920) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
headers = ['lang',  'created_at', 'text', 
           'user.id_str', 'user.name', 'user.screen_name', 'user.created_at', 'user.statuses_count',
           'user.location', 'user.verified', 'user.followers_count', 'user.friends_count', 
           'user.listed_count']#'id_str',
#            'coordinates', 'place',
#            'quoted_status.id_str', 'extended_tweet.full_text', 'entities.hashtags.', 
#            'entities.symbols.', 'geo', 'retweet_count']

# %%
# df = df.set_index('id_str')

# %%
df.head(1)
# Out:
#                      contributors  coordinates coordinates.coordinates.  \
# id_str
# 1294855064901652480           NaN          NaN                      NaN
#
#                     coordinates.type                      created_at  \
# id_str
# 1294855064901652480              NaN  Sun Aug 16 04:34:39 +0000 2020
#
#                     display_text_range.  entities.hashtags.  \
# id_str
# 1294855064901652480              0, 140                 NaN
#
#                     entities.hashtags.hashtags.indices.  \
# id_str
# 1294855064901652480                                 NaN
#
#                     entities.hashtags.hashtags.text  \
# id_str
# 1294855064901652480                             NaN
#
#                     entities.media.media.additional_media_info.description  \
# id_str
# 1294855064901652480                                                NaN
#
#                     entities.media.media.additional_media_info.embeddable  \
# id_str
# 1294855064901652480                                                NaN
#
#                     entities.media.media.additional_media_info.monetizable  \
# id_str
# 1294855064901652480                                                NaN
#
#                      ... user.profile_sidebar_border_color  \
# id_str               ...
# 1294855064901652480  ...                            000000
#
#                     user.profile_sidebar_fill_color user.profile_text_color  \
# id_str
# 1294855064901652480                          000000                  000000
#
#                     user.profile_use_background_image  user.protected  \
# id_str
# 1294855064901652480                             False           False
#
#                      user.screen_name user.statuses_count user.time_zone  \
# id_str
# 1294855064901652480   mariaclarinda86                2769            NaN
#
#                     user.translator_type  user.url user.utc_offset  \
# id_str
# 1294855064901652480                 none       NaN             NaN
#
#                      user.verified
# id_str
# 1294855064901652480          False
#
# [1 rows x 1005 columns]

# %%
# list(df.columns)[0:500]

# %%
# list(df.columns)[500:]

# %%
dff = df[headers]

# %%
dff['user.ratio'] = dff['user.followers_count']/dff['user.friends_count']
dff['user.ratio']= dff['user.ratio'].dropna()
# Out:
# <ipython-input-87-ec4d755d8bf6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['user.ratio'] = dff['user.followers_count']/dff['user.friends_count']
# <ipython-input-87-ec4d755d8bf6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['user.ratio']= dff['user.ratio'].dropna()

# %%
dff.columns
# Out:
# Index(['lang', 'created_at', 'text', 'user.id_str', 'user.name',
#        'user.screen_name', 'user.created_at', 'user.statuses_count',
#        'user.location', 'user.verified', 'user.followers_count',
#        'user.friends_count', 'user.listed_count', 'user.ratio'],
#       dtype='object')

# %%
dff.nunique()
# Out:
# lang                       39
# created_at              15587
# text                    12967
# user.id_str             35005
# user.name               33397
# user.screen_name        35006
# user.created_at         35000
# user.statuses_count     23952
# user.location           13184
# user.verified               2
# user.followers_count     4939
# user.friends_count       4233
# user.listed_count         507
# user.ratio              28463
# dtype: int64

# %%
# dff.dropna(subset=['quoted_status.id_str'])

# %%
dff["user.location"].value_counts()
# Out:
# Lagos, Nigeria                 361
# India                          273
# Nigeria                        234
# United States                  234
# Republic of the Philippines    190
#                               ...
# opposite your village            1
# mahina. ooc20+                   1
# Bs As, Argentina                 1
# Burial Mounds                    1
# ...479 📍                         1
# Name: user.location, Length: 13184, dtype: int64

# %%
a = dff.dropna(subset=['lang'])

# %%
# a[a["lang"]!="en"].lang.value_counts()

# %%
ax = a[a["lang"]!="en"].lang.value_counts().head(20).plot.bar(figsize=(12,5), colormap='Spectral')
# ax = a["lang"].value_counts().head(20).plot.bar(figsize=(12,5), colormap='Spectral')
ax.set_title('Tweet counts excluding English Language')
ax.title.set_size(20)
ax.tick_params(labelsize=15)
ax.set_xlabel('Language Code', fontsize=20)
ax.set_ylabel('Number of Tweets',fontsize=20)
plt.show()

# %%
dfen = dff[df['lang']== 'en']
dfen = dfen.reset_index(drop=True)

# %%
dff['user.verified'] = dff['user.verified'].apply({False:'Not Verified', True:'Verified'}.get)
# Out:
# <ipython-input-96-c254cf2f92cc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['user.verified'] = dff['user.verified'].apply({False:'Not Verified', True:'Verified'}.get)

# %%
dff['user.verified'].value_counts()
# Out:
# Not Verified    38843
# Verified          180
# Name: user.verified, dtype: int64

# %%
ax = dff['user.verified'].value_counts().plot.bar(figsize=(10,8), colormap='Spectral')
for p in ax.patches:
    ax.annotate( p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=15)
#     ax.annotate("%.2f" % p.get_width(), (p.get_x() + p.get_width(), p.get_y()), xytext=(5, 10), textcoords='offset points')

ax.set_title('Verified  users Tweeting about online Gaming')
ax.title.set_size(20)
ax.tick_params(labelsize=15)
ax.set_xlabel('Verified Status', fontsize=20)
ax.set_ylabel('Number of Users',fontsize=20)
plt.show()

# %%
dff['user.ratio'] = dff['user.ratio'].round(2)
# Out:
# <ipython-input-105-0ba44aaf2c1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff['user.ratio'] = dff['user.ratio'].round(2)

# %%
dff[['user.ratio']]
# Out:
#                      user.ratio
# id_str
# 1294855064901652480        1.60
# 1294855067581976576        1.58
# 1294855070572453889        0.19
# 1294855072694894593        1.11
# 1294855073189617664        0.68
# ...                         ...
# 1294928579122343936        0.09
# 1294928580410040320        1.11
# 1294928582360346625        0.66
# 1294928591747035136        0.54
# 1294928591701123073        1.35
#
# [39023 rows x 1 columns]

# %%
dff['user.ratio'].value_counts()
# Out:
# 0.00       788
# 0.04       562
# 0.08       509
# 0.07       496
# 0.06       471
#           ...
# 9.26         1
# 7.08         1
# 54.73        1
# 1405.67      1
# 21.61        1
# Name: user.ratio, Length: 1840, dtype: int64

# %%
c = dff['user.ratio'].value_counts()

# %%
filtered = c[c >= 2]
r = dff[dff['user.ratio'].isin(filtered.index)]

# %%
ratios = dff[dff['user.ratio'] > 0.5]
ratios = ratios[ratios['user.ratio'] < 50]

# %%
ax = ratios['user.ratio'].hist(bins=10,figsize=(12,8))
ax.set_title('Verified  users Tweeting about online Gaming')
ax.title.set_size(20)
ax.tick_params(labelsize=15)
ax.set_xlabel('Verified Status', fontsize=20)
ax.set_ylabel('Number of Users',fontsize=20)
plt.show()

# %%
rr = dff[dff['user.friends_count'] > 5]
rr = rr[rr['user.friends_count'] < 5000]

rr = rr[rr['user.followers_count'] > 5]
rr = rr[rr['user.followers_count'] < 5000]

# %%
# ax = rr.plot(x='user.friends_count', y='user.followers_count', figsize=(16, 8))
ax = rr.plot.scatter(x='user.friends_count', y='user.followers_count', figsize=(16, 8))
ax.set_title('Verified  users Tweeting about online Gaming')
ax.title.set_size(20)
ax.tick_params(labelsize=15)
# ax.set_xlabel('Verified Status', fontsize=20)
# ax.set_ylabel('Number of Users',fontsize=20)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
rr['user.followers_count'].hist(bins=100, figsize=(16,8))
# Out:
# <AxesSubplot:>

# %%
rr = dff[dff['user.friends_count'] > 5]
rr = rr[rr['user.friends_count'] > 10000]

rr = rr[rr['user.followers_count'] > 5]
rr = rr[rr['user.followers_count'] < 100000]

# ax = rr.plot(x='user.friends_count', y='user.followers_count', figsize=(14, 8))
ax = rr.plot.scatter(x='user.friends_count', y='user.followers_count', figsize=(14, 8))
ax.set_title('Verified  users Tweeting about online Gaming')
ax.title.set_size(20)
ax.tick_params(labelsize=15)
# ax.set_xlabel('Verified Status', fontsize=20)
# ax.set_ylabel('Number of Users',fontsize=20)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
df
# Out:
#        contributors  coordinates coordinates.coordinates. coordinates.type  \
# 0               NaN          NaN                      NaN              NaN
# 1               NaN          NaN                      NaN              NaN
# 2               NaN          NaN                      NaN              NaN
# 3               NaN          NaN                      NaN              NaN
# 4               NaN          NaN                      NaN              NaN
# ...             ...          ...                      ...              ...
# 39018           NaN          NaN                      NaN              NaN
# 39019           NaN          NaN                      NaN              NaN
# 39020           NaN          NaN                      NaN              NaN
# 39021           NaN          NaN                      NaN              NaN
# 39022           NaN          NaN                      NaN              NaN
#
#                            created_at display_text_range.  entities.hashtags.  \
# 0      Sun Aug 16 04:34:39 +0000 2020              0, 140                 NaN
# 1      Sun Aug 16 04:34:40 +0000 2020                 NaN                 NaN
# 2      Sun Aug 16 04:34:40 +0000 2020                 NaN                 NaN
# 3      Sun Aug 16 04:34:41 +0000 2020                 NaN                 NaN
# 4      Sun Aug 16 04:34:41 +0000 2020                 NaN                 NaN
# ...                               ...                 ...                 ...
# 39018  Sun Aug 16 09:26:46 +0000 2020                 NaN                 NaN
# 39019  Sun Aug 16 09:26:46 +0000 2020                 NaN                 NaN
# 39020  Sun Aug 16 09:26:47 +0000 2020                 NaN                 NaN
# 39021  Sun Aug 16 09:26:49 +0000 2020                 NaN                 NaN
# 39022  Sun Aug 16 09:26:49 +0000 2020                 NaN                 NaN
#
#       entities.hashtags.hashtags.indices. entities.hashtags.hashtags.text  \
# 0                                     NaN                             NaN
# 1                                     NaN                             NaN
# 2                                 90, 108               TerusBergerakMaju
# 3                                     NaN                             NaN
# 4                                     NaN                             NaN
# ...                                   ...                             ...
# 39018                                 NaN                             NaN
# 39019                                 NaN                             NaN
# 39020                                 NaN                             NaN
# 39021                              27, 33                           ASTRO
# 39022                                 NaN                             NaN
#
#       entities.media.media.additional_media_info.description  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39018                                                NaN
# 39019                                                NaN
# 39020                                                NaN
# 39021                                                NaN
# 39022                                                NaN
#
#       entities.media.media.additional_media_info.embeddable  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 39018                                                NaN
# 39019                                                NaN
# 39020                                                NaN
# 39021                                                NaN
# 39022                                                NaN
#
#       entities.media.media.additional_media_info.monetizable  ...  \
# 0                                                    NaN      ...
# 1                                                    NaN      ...
# 2                                                    NaN      ...
# 3                                                    NaN      ...
# 4                                                  False      ...
# ...                                                  ...      ...
# 39018                                                NaN      ...
# 39019                                                NaN      ...
# 39020                                                NaN      ...
# 39021                                                NaN      ...
# 39022                                                NaN      ...
#
#       user.profile_sidebar_border_color user.profile_sidebar_fill_color  \
# 0                                000000                          000000
# 1                                C0DEED                          DDEEF6
# 2                                FFFFFF                          DDEEF6
# 3                                C0DEED                          DDEEF6
# 4                                C0DEED                          DDEEF6
# ...                                 ...                             ...
# 39018                            C0DEED                          DDEEF6
# 39019                            C0DEED                          DDEEF6
# 39020                            C0DEED                          DDEEF6
# 39021                            C0DEED                          DDEEF6
# 39022                            000000                          000000
#
#       user.profile_text_color user.profile_use_background_image  \
# 0                      000000                             False
# 1                      333333                              True
# 2                      333333                              True
# 3                      333333                              True
# 4                      333333                              True
# ...                       ...                               ...
# 39018                  333333                              True
# 39019                  333333                              True
# 39020                  333333                              True
# 39021                  333333                              True
# 39022                  000000                             False
#
#        user.protected  user.screen_name user.statuses_count user.time_zone  \
# 0               False   mariaclarinda86                2769            NaN
# 1               False           AGBaduy                1589            NaN
# 2               False    ReiPilBarCikut               88940            NaN
# 3               False     _JenniferMean               59633            NaN
# 4               False         imaubreyy                 380            NaN
# ...               ...               ...                 ...            ...
# 39018           False           binny73                 340            NaN
# 39019           False          ay_nasir               67243            NaN
# 39020           False        duchesskae                7836            NaN
# 39021           False           itsm_kp                6851            NaN
# 39022           False        tatakenny_               54433            NaN
#
#       user.translator_type                user.url user.utc_offset  \
# 0                     none                     NaN             NaN
# 1                     none                     NaN             NaN
# 2                     none                     NaN             NaN
# 3                     none                     NaN             NaN
# 4                     none                     NaN             NaN
# ...                    ...                     ...             ...
# 39018                 none                     NaN             NaN
# 39019                 none                     NaN             NaN
# 39020                 none  http://meghanpedia.com             NaN
# 39021                 none                     NaN             NaN
# 39022                 none                     NaN             NaN
#
#        user.verified
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ...              ...
# 39018          False
# 39019          False
# 39020          False
# 39021          False
# 39022          False
#
# [39023 rows x 1005 columns]

# %%
# df.plot.hist(bins=12, alpha=0.5)
