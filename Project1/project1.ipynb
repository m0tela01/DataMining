# %%
import os
import re
import csv
import numpy as np
import pandas as pd

# %%
location = "C:\\Users\\Telahun\\Documents\\School\\CSE 632\\data\\"

# %%
df = pd.read_csv(location+"games.csv", error_bad_lines=False)
# Out:
# , saw 506\nSkipping line 55021: expected 463 fields, saw 490\nSkipping line 55030: expected 463 fields, saw 489\nSkipping line 55126: expected 463 fields, saw 525\nSkipping line 55129: expected 463 fields, saw 533\nSkipping line 55153: expected 463 fields, saw 490\nSkipping line 55183: expected 463 fields, saw 529\nSkipping line 55195: expected 463 fields, saw 491\nSkipping line 55258: expected 463 fields, saw 486\nSkipping line 55324: expected 463 fields, saw 490\nSkipping line 55405: expected 463 fields, saw 490\nSkipping line 55471: expected 463 fields, saw 539\nSkipping line 55492: expected 463 fields, saw 514\nSkipping line 55564: expected 463 fields, saw 587\nSkipping line 55591: expected 463 fields, saw 473\nSkipping line 55654: expected 463 fields, saw 484\nSkipping line 55663: expected 463 fields, saw 483\nSkipping line 55723: expected 463 fields, saw 605\nSkipping line 55732: expected 463 fields, saw 529\nSkipping line 55834: expected 463 fields, saw 517\nSkipping line 5584
# ...

# %%
df.head(1)
# Out:
# round_image_url:"http:\/\/abs.twim... profile_background_image_url_https:"https:\/\/a... profile_background_tile:false profile_link_color:"FF3300" profile_sidebar_border_color:"86A4A6" profile_sidebar_fill_color:"A0C5C7" profile_text_color:"333333" profile_use_background_image:true profile_image_url:"http:\/\/pbs.twimg.com\/prof... profile_image_url_https:"https:\/\/pbs.twimg.co... profile_banner_url:"https:\/\/pbs.twimg.com\/pr... default_profile:false default_profile_image:false following:null follow_request_sent:null notifications:null} geo:null coordinates:null place:null contributors:null is_quote_status:false quote_count:915 reply_count:4439 retweet_count:3280 favorite_count:6142 entities:{"hashtags":[] urls:[] user_mentions:[{"screen_name":"lopezobrador_" name:"Andr\u00e9s Manuel" id:82119937 id_str:"82119937" indices:[14 28]}] symbols:[] media:[{"id":1294603424030433282 id_str:"1294603424030433282" indices:[94 117] additional_media_info:{"monetizable":false} media_url:"http:\
# ...
